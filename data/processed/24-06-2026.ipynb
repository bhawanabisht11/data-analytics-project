# %%
import pandas as pd
import os

# Path to your raw data folder
data_path = r"C:\Users\Bhanu Bisht\Data_Analytics_Project\data\raw"

# Get all CSV files
csv_files = [f for f in os.listdir(data_path) if f.endswith('.csv')]

print(f"Found {len(csv_files)} CSV files\n")

# Dictionary to store DataFrames
datasets = {}

for file in csv_files:
    file_path = os.path.join(data_path, file)

    try:
        df = pd.read_csv(file_path)

        datasets[file] = df

        print("=" * 60)
        print(f"Dataset: {file}")
        print(f"Shape: {df.shape}")
        print("\nData Types:")
        print(df.dtypes)
        print("\nFirst 5 Rows:")
        print(df.head())
        print("\n")

    except Exception as e:
        print(f"Error loading {file}: {e}")
# Out:
# Found 10 CSV files
#
# ...
# Dataset: 01_fund_master.csv
# Shape: (40, 15)
#
# Data Types:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
import pandas as pd
import os

data_path = r"C:\Users\Bhanu Bisht\Data_Analytics_Project\data\raw"

csv_files = [f for f in os.listdir(data_path) if f.endswith(".csv")]

print(f"Found {len(csv_files)} CSV files")

datasets = {}

for file in csv_files:
    print("\n" + "="*80)
    print(f"DATASET: {file}")

    file_path = os.path.join(data_path, file)

    try:
        df = pd.read_csv(file_path)
        datasets[file] = df

        print("\nShape:")
        print(df.shape)

        print("\nData Types:")
        print(df.dtypes)

        print("\nFirst 5 Rows:")
        print(df.head())

        print("\nPotential Anomalies:")
        print(f"Missing Values: {df.isnull().sum().sum()}")
        print(f"Duplicate Rows: {df.duplicated().sum()}")

        object_cols = df.select_dtypes(include='object').columns
        if len(object_cols) > 0:
            print(f"Text Columns: {list(object_cols)}")

    except Exception as e:
        print(f"Error loading {file}: {e}")
# Out:
# Found 10 CSV files
#
# ...
# DATASET: 01_fund_master.csv
#
# Shape:
# (40, 15)
#
# Data Types:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
import pandas as pd

df = pd.read_csv("C:/Users/Bhanu Bisht/Data_Analytics_Project/data/raw/01_fund_master.csv")

print("Shape:")
print(df.shape)

print("\nData Types:")
print(df.dtypes)

print("\nFirst 5 Rows:")
print(df.head())
# Out:
# Shape:
# (40, 15)
#
# Data Types:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object
#
# First 5 Rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# ...

# %%
# Basic Information

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
print(df.shape)
# Out:
# (40, 15)

# %%
# Missing Values

# %%
print(df.isnull().sum())
# Out:
# amfi_code             0
# fund_house            0
# scheme_name           0
# category              0
# sub_category          0
# plan                  0
# launch_date           0
# benchmark             0
# expense_ratio_pct     0
# exit_load_pct         0
# min_sip_amount        0
# min_lumpsum_amount    0
# fund_manager          0
# risk_category         0
# sebi_category_code    0
# dtype: int64

# %%
# Duplicate Records

# %%
print("Duplicate rows:", df.duplicated().sum())
# Out:
# Duplicate rows: 0

# %%
# Unique Values

# %%
print(df['scheme_name'].nunique())  # replace with actual column name
# Out:
# 40

# %%
# Number of fund houses
print(df['fund_house'].nunique())

# Categories
print(df['category'].nunique())

# Fund managers
print(df['fund_manager'].nunique())
# Out:
# 10
# 2
# 29

# %%
# Check Numeric Columns

# %%
print(df.describe())
# Out:
#            amfi_code  expense_ratio_pct  exit_load_pct  min_sip_amount  \
# count      40.000000          40.000000      40.000000            40.0
# mean   120247.000000           1.237000       0.812500           500.0
# std     14534.998667           0.386584       0.387091             0.0
# min    100016.000000           0.550000       0.000000           500.0
# 25%    118632.750000           0.787500       1.000000           500.0
# 50%    119551.500000           1.425000       1.000000           500.0
# 75%    120842.250000           1.540000       1.000000           500.0
# max    149324.000000           1.640000       1.000000           500.0
#
#        min_lumpsum_amount
# count           40.000000
# mean          1277.500000
# std           1082.847031
# min            100.000000
# 25%           1000.000000
# 50%           1000.000000
# 75%           1000.000000
# max           5000.000000

# %%
# Check Text Columns

# %%
print(df.describe(include='object'))
# Out:
#              fund_house                                scheme_name category  \
# count                40                                         40       40
# unique               10                                         40        2
# top     SBI Mutual Fund  SBI Bluechip Fund - Regular Plan - Growth   Equity
# freq                  5                                          1       34
#
#        sub_category     plan launch_date      benchmark   fund_manager  \
# count            40       40          40             40             40
# unique           12        2          34             10             29
# top       Large Cap  Regular  2013-01-01  NIFTY 100 TRI  Sohini Andani
# freq             14       32           7             14              2
#
#        risk_category sebi_category_code
# count             40                 40
# unique             5                  9
# top         Moderate               EC01
# freq              16                 14

# %%
# print("\nSummary Statistics:")

# %%
print(df.describe(include='all'))
# Out:
#             amfi_code       fund_house  \
# count       40.000000               40
# unique            NaN               10
# top               NaN  SBI Mutual Fund
# freq              NaN                5
# mean    120247.000000              NaN
# std      14534.998667              NaN
# min     100016.000000              NaN
# 25%     118632.750000              NaN
# 50%     119551.500000              NaN
# 75%     120842.250000              NaN
# max     149324.000000              NaN
#
#                                       scheme_name category sub_category  \
# count                                          40       40           40
# unique                                         40        2           12
# top     SBI Bluechip Fund - Regular Plan - Growth   Equity    Large Cap
# freq                                            1       34           14
# mean                                          NaN      NaN          NaN
# ...

# %%
#Check Data Types

# %%
print(df.dtypes)
# Out:
# amfi_code               int64
# fund_house             object
# scheme_name            object
# category               object
# sub_category           object
# plan                   object
# launch_date            object
# benchmark              object
# expense_ratio_pct     float64
# exit_load_pct         float64
# min_sip_amount          int64
# min_lumpsum_amount      int64
# fund_manager           object
# risk_category          object
# sebi_category_code     object
# dtype: object

# %%
""" Anomalies:

Date columns stored as object
Numeric columns stored as text
"""
# Out:
# ' Anomalies:\n\nDate columns stored as object\nNumeric columns stored as text\n'
